# %% [markdown]
# <a href="https://colab.research.google.com/github/MaheswaraPradeep/SE-LAB-TASKS/blob/main/SE_lab_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
# Hardcoding variables which has static values assigned
a = 1
b = 2
c = 3
def weather_model(x):
 return a * x**2 + b * x + c
x_values = np.linspace(0, 10, 100)
y_values = weather_model(x_values)
plt.plot(x_values, y_values, label='Weather Model')
plt.title('Weather Modeling')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Keyboard input
def weather_model(x, a, b, c):
 return a*x**2 + b*x + c
a = float(input("Enter the value of a: "))
b = float(input("Enter the value of b: "))
c = float(input("Enter the value of c: "))
x_values = np.linspace(0, 10, 400)
y_values = weather_model(x_values, a, b, c)
x_specific = float(input("Enter the value of x: "))
y_specific = weather_model(x_specific, a, b, c)
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label=f'{a}x^2 + {b}x + {c}')
plt.plot([x_specific], [y_specific], 'ro')
plt.title('Weather Model')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Enter the value of a: 1
# Enter the value of b: 3
# Enter the value of c: 2
# Enter the value of x: 1

# %%
#Input from text file
def weather_model(x, a, b, c):
 return a * np.power(x, 2) + b * x + c
parameters = np.loadtxt('sample_data/nani.txt')
x_values = np.linspace(-10, 10, 400)
plt.figure(figsize=(10, 6))
for test in parameters:
 x, a, b, c = test
 y_values = weather_model(x_values, a, b, c)
 plt.plot(x_values, y_values, label=f'{a}x^2 + {b}x + {c}')
plt.title('Quadratic Functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
def weather_model(x, a, b, c):
 return a * x**2 + b * x + c
with open('sample_data/nani.txt', 'r') as f:
 line = f.readline()
 x_specific, a_specific, b_specific, c_specific = map(float,
line.split())
x_values = np.linspace(-10, 10, 400)
y_values = weather_model(x_values, a_specific, b_specific, c_specific)
y_specific = weather_model(x_specific, a_specific, b_specific,
c_specific)
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label=f'{a_specific}x^2 + {b_specific}x +{c_specific}')
plt.plot(x_specific, y_specific, 'ro', label=f'Specific Point({x_specific}, {y_specific})')
plt.title('Quadratic Function')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Multi set of input
def weather_model(x, a, b, c):
 return a * x**2 + b * x + c
with open('sample_data/nani.txt', 'r') as f:
 lines = f.readlines()
x_values = np.linspace(-10, 10, 400)
plt.figure(figsize=(10, 6))
for line in lines:
 x_specific, a, b, c = map(float, line.split())
 y_values = weather_model(x_values, a, b, c)
 y_specific = weather_model(x_specific, a, b, c)
 plt.plot(x_values, y_values, label=f'{a}x^2 + {b}x + {c}')
 plt.plot(x_specific, y_specific, 'ro')
plt.title('Quadratic Functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
